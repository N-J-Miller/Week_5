# %% [markdown]
# # What's the Weather Like?
# ####  Python requests, APIs, and JSON traversals combine to answer a fundamental question: "What's the weather like as we approach the equator?"

# %% [markdown]
# This project will use a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. The project will utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api) to create a representative model of weather across world cities.
#
# Visualizations will shocase the following relationships:
#
# * Temperature ($^\circ$F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude

# %% [markdown]
# ##### Dependencies and Setup

# %%
# Dependencies and Setup provided by class instructor:
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities provided by class instructor:
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ##### Sample of JSON data for reference:

# %%
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID='+ api_key
city = 'st. louis'

req = requests.get(base_url + f'&q={city}')
print()

#create a json output of the data

json_data = req.json()
print(json_data)
# Out:
# {'coord': {'lon': -90.1979, 'lat': 38.6273}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 48.02, 'feels_like': 47.03, 'temp_min': 43.07, 'temp_max': 51.94, 'pressure': 1018, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 170}, 'clouds': {'all': 90}, 'dt': 1634959351, 'sys': {'type': 1, 'id': 3689, 'country': 'US', 'sunrise': 1634905027, 'sunset': 1634944380}, 'timezone': -18000, 'id': 4407066, 'name': 'St Louis', 'cod': 200}

# %% [markdown]
# ## Compiling the Data
# ### Creating a weather database for cities in above list using API calls and including a log of cities checked:

# %%
City_Data = {'City':[],
             'Country':[],
             'Coordinates': [],
             'Max Temperature' : [],
             'Humidity':[],
             'Pressure':[],
             'Cloudiness' : [],
             'Wind Speed': [], 
             'Date' : []}

#loop over cities and add data to dictionary
for city in cities:

    try:
        base_url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID='+ api_key   
    #q represents the city
        req = requests.get(base_url + f'&q={city}')
    
        data = req.json()
    
    #add values to our city_weather dictionary
        City_Data['City'].append(data['name'])
        City_Data['Country'].append(data['sys']['country'])
        City_Data['Coordinates'].append(data['coord'])
        City_Data['Max Temperature'].append(data['main']['temp_max'])
        City_Data['Humidity'].append(data['main']['humidity'])
        City_Data['Pressure'].append(data['main']['pressure'])
        City_Data['Cloudiness'].append(data['clouds']['all'])
        City_Data['Wind Speed'].append(data['wind']['speed'])
        City_Data['Date'].append(data['dt'])
        
        print("Processing City:" + city)
    
    except:
        print(city+ ' Not Found')
        pass
# Out:
# nizhneyansk Not Found
# Processing City:rikitea
# Processing City:kapaa
# Processing City:solnechnyy
# Processing City:mataura
# Processing City:san patricio
# Processing City:tazovskiy
# Processing City:ushuaia
# Processing City:jamestown
# Processing City:cascais
# Processing City:bambous virieux
# Processing City:port alfred
# Processing City:cape town
# Processing City:avarua
# Processing City:hobart
# Processing City:punta arenas
# Processing City:bluff
# Processing City:hilo
# karamea Not Found
# Processing City:celestun
# Processing City:boa vista
# Processing City:cacheu
# Processing City:aklavik
# mys shmidta Not Found
# Processing City:new norfolk
# Processing City:nyurba
# Processing City:atasu
# Processing City:arman
# Processing City:masallatah
# Processing City:hermanus
# artyk Not Found
# Processing City:starosubkhangulovo
# Processing City:albany
# Processing City:filadelfia
# Processing City:atuona
# Processing City:yellowknife
# Processing City:zheleznodorozhnyy
# Processing City:carmelo
# Processing City:puerto ayora
# Processing City:vaini
# Processing City:cherskiy
# Processing City:necochea
# Processing City:lesnoy
# solovetskiy Not Found
# belushya guba Not Found
# Processing City:wanning
# Processing City:saint-augustin
# Processing City:saskylakh
# Processing City:iqaluit
# Processing City:buala
# Processing City:agogo
# Processing City:bilma
# Processing City:quechultenango
# Processing City:lebu
# Processing City:luena
# Processing City:barrow
# attawapiskat Not Found
# Processing City:marawi
# Processing City:luderitz
# Processing City:ponta do sol
# Processing City:tura
# Processing City:michalovce
# Processing City:norman wells
# taolanaro Not Found
# Processing City:teguldet
# Processing City:pevek
# grand river south east Not Found
# Processing City:bredasdorp
# Processing City:thompson
# Processing City:maragogi
# Processing City:sur
# Processing City:svetlogorsk
# Processing City:kalispell
# Processing City:labuhan
# Processing City:talalora
# Processing City:bouna
# Processing City:zhenlai
# Processing City:algete
# Processing City:nhulunbuy
# Processing City:honiara
# Processing City:lasa
# Processing City:saint-philippe
# Processing City:huarmey
# Processing City:georgetown
# Processing City:aleksandrov gay
# Processing City:namibe
# barentsburg Not Found
# Processing City:okakarara
# Processing City:amahai
# Processing City:faya
# Processing City:kidal
# Processing City:inhambane
# Processing City:saldanha
# Processing City:provideniya
# Processing City:pangnirtung
# Processing City:bethel
# Processing City:cermik
# Processing City:clyde river
# Processing City:klaksvik
# Processing City:taksimo
# Processing City:rusape
# Processing City:salalah
# Processing City:nikolskoye
# Processing City:geraldton
# Processing City:busselton
# Processing City:suluq
# Processing City:portland
# Processing City:bubaque
# Processing City:mount gambier
# Processing City:castro
# Processing City:hasaki
# aflu Not Found
# Processing City:betioky
# Processing City:beyneu
# Processing City:alofi
# Processing City:haines junction
# Processing City:itupiranga
# Processing City:havoysund
# kazalinsk Not Found
# Processing City:grand-santi
# Processing City:hovd
# Processing City:tasiilaq
# lolua Not Found
# Processing City:aksu
# Processing City:areosa
# Processing City:dunedin
# Processing City:qingquan
# Processing City:tuktoyaktuk
# Processing City:talnakh
# Processing City:lake havasu city
# Processing City:port elizabeth
# Processing City:cartagena del chaira
# Processing City:ribeira grande
# Processing City:bandarbeyla
# Processing City:butaritari
# Processing City:mar del plata
# Processing City:cabo san lucas
# Processing City:arraial do cabo
# Processing City:chuy
# Processing City:broome
# Processing City:lugoba
# Processing City:trairi
# Processing City:khatanga
# Processing City:never
# Processing City:zhanaozen
# Processing City:thinadhoo
# Processing City:oistins
# Processing City:tateyama
# Processing City:east london
# Processing City:marzuq
# Processing City:hobyo
# Processing City:bonthe
# Processing City:leh
# Processing City:kamenka
# Processing City:dikson
# chelyabinsk-70 Not Found
# Processing City:vuktyl
# Processing City:alekseyevsk
# Processing City:sao domingos
# Processing City:jaciara
# Processing City:churu
# kuche Not Found
# Processing City:severo-kurilsk
# Processing City:koroni
# Processing City:flin flon
# Processing City:dombarovskiy
# Processing City:kaya
# Processing City:ust-nera
# Processing City:berga
# Processing City:kuah
# Processing City:constitucion
# Processing City:sunrise manor
# Processing City:springfield
# Processing City:manoel urbano
# Processing City:kaitangata
# Processing City:phalaborwa
# Processing City:kavieng
# Processing City:shimoda
# Processing City:college
# palabuhanratu Not Found
# Processing City:te anau
# Processing City:beringovskiy
# Processing City:jesup
# Processing City:souillac
# Processing City:balancan
# marcona Not Found
# Processing City:sao joao da barra
# Processing City:gat
# Processing City:poum
# Processing City:guerrero negro
# Processing City:wajima
# Processing City:santa fe
# Processing City:limbang
# Processing City:chokurdakh
# Processing City:kamina
# Processing City:puerto quijarro
# Processing City:bafoulabe
# Processing City:alta floresta
# Processing City:onega
# Processing City:lakes entrance
# Processing City:the valley
# Processing City:qaanaaq
# Processing City:ihlow
# Processing City:ixtapa
# Processing City:nanortalik
# Processing City:upernavik
# Processing City:katsuura
# Processing City:egvekinot
# Processing City:hithadhoo
# Processing City:calvillo
# Processing City:itarema
# Processing City:khorinsk
# tsihombe Not Found
# Processing City:mamlyutka
# Processing City:victoria
# Processing City:ukiah
# Processing City:susangerd
# Processing City:codrington
# Processing City:kasama
# Processing City:vanimo
# Processing City:narsaq
# Processing City:ahipara
# Processing City:komsomolets
# Processing City:amtala
# Processing City:kaniama
# Processing City:muravlenko
# Processing City:vinh long
# Processing City:south lake tahoe
# buariki Not Found
# Processing City:kalmunai
# halalo Not Found
# Processing City:tsaratanana
# Processing City:kodiak
# Processing City:susehri
# Processing City:pangai
# Processing City:los llanos de aridane
# Processing City:cockburn town
# Processing City:kudahuvadhoo
# Processing City:bobrovytsya
# Processing City:gamba
# Processing City:hvolsvollur
# Processing City:port-cartier
# bolshiye uki Not Found
# Processing City:takoradi
# Processing City:yar-sale
# Processing City:tuatapere
# Processing City:hamilton
# Processing City:fort smith
# Processing City:esperance
# Processing City:puerto escondido
# Processing City:kruisfontein
# Processing City:manokwari
# Processing City:belluno
# Processing City:jalingo
# Processing City:rockport
# Processing City:ilulissat
# Processing City:dakar
# Processing City:mahebourg
# Processing City:kumluca
# Processing City:carlagan
# Processing City:miyako
# Processing City:puerto palomas
# Processing City:lodja
# Processing City:oussouye
# Processing City:torbay
# Processing City:dongsheng
# Processing City:mackay
# Processing City:aguimes
# Processing City:zhezkazgan
# Processing City:mao
# Processing City:evans
# Processing City:bathsheba
# illoqqortoormiut Not Found
# Processing City:shizunai
# Processing City:port hedland
# Processing City:marfino
# Processing City:fortuna
# Processing City:metro
# Processing City:carnarvon
# Processing City:galion
# Processing City:nome
# Processing City:flinders
# bina-etawa Not Found
# Processing City:yinchuan
# Processing City:tiksi
# Processing City:half moon bay
# Processing City:borba
# Processing City:shamli
# Processing City:meadow lake
# Processing City:sao filipe
# Processing City:frontera
# Processing City:mogadishu
# Processing City:pangody
# Processing City:basco
# Processing City:buchanan
# Processing City:iquique
# Processing City:jalu
# Processing City:eureka
# skalistyy Not Found
# Processing City:saint george
# utiroa Not Found
# Processing City:omboue
# Processing City:igrim
# Processing City:mount isa
# Processing City:mapiripan
# Processing City:micheweni
# Processing City:nagua
# Processing City:montepuez
# Processing City:moose factory
# Processing City:lorengau
# Processing City:humberto de campos
# Processing City:kuantan
# Processing City:christchurch
# Processing City:dogondoutchi
# Processing City:pangkalanbuun
# Processing City:san carlos de bariloche
# Processing City:uyuni
# Processing City:nacozari
# Processing City:namanga
# Processing City:mandera
# Processing City:touros
# Processing City:ndola
# Processing City:kamiiso
# Processing City:batemans bay
# Processing City:ossora
# Processing City:carmen
# Processing City:matara
# Processing City:rocha
# Processing City:airai
# Processing City:kampene
# Processing City:grimshaw
# Processing City:coihaique
# Processing City:umm lajj
# Processing City:nemuro
# Processing City:coolum beach
# Processing City:sao jose da coroa grande
# Processing City:lagoa
# Processing City:kenai
# Processing City:magistralnyy
# Processing City:bella vista
# Processing City:sturgis
# Processing City:kuala terengganu
# Processing City:toamasina
# Processing City:mackenzie
# Processing City:kyotera
# sentyabrskiy Not Found
# Processing City:lamu
# Processing City:greenville
# Processing City:dingle
# Processing City:murgab
# Processing City:axim
# Processing City:wagar
# Processing City:isangel
# Processing City:wad madani
# Processing City:plettenberg bay
# amderma Not Found
# tumannyy Not Found
# Processing City:muros
# Processing City:chinsali
# Processing City:thongwa
# Processing City:sijunjung
# vaitupu Not Found
# Processing City:luwingu
# Processing City:wenling
# Processing City:kholtoson
# Processing City:mataram
# Processing City:mitsamiouli
# Processing City:baykit
# Processing City:lompoc
# Processing City:sabha
# Processing City:saint-paul
# Processing City:zambezi
# Processing City:buritis
# Processing City:sungairaya
# Processing City:hua hin
# Processing City:komsomolskiy
# Processing City:marystown
# Processing City:ostrovnoy
# Processing City:duxbury
# Processing City:hauterive
# Processing City:rio gallegos
# Processing City:hillsborough
# Processing City:dalvik
# Processing City:saint-pierre
# Processing City:rodrigues alves
# Processing City:poquoson
# Processing City:araouane
# Processing City:udachnyy
# Processing City:prattville
# Processing City:uige
# haapu Not Found
# Processing City:anjar
# kollumerland Not Found
# Processing City:husavik
# Processing City:garsten
# Processing City:lusambo
# Processing City:schattdorf
# Processing City:najran
# Processing City:beniganj
# Processing City:plouzane
# Processing City:tallahassee
# Processing City:kokopo
# Processing City:pallisa
# Processing City:makakilo city
# Processing City:meulaboh
# Processing City:kiama
# Processing City:dwarka
# Processing City:longyearbyen
# Processing City:pisco
# Processing City:tshane
# Processing City:tooele
# Processing City:byron bay
# Processing City:porto novo
# Processing City:verkhnevilyuysk
# Processing City:padang
# tabiauea Not Found
# Processing City:shenjiamen
# Processing City:liyang
# Processing City:pacific grove
# Processing City:tagusao
# tharrawaddy Not Found
# Processing City:sonda
# Processing City:kuandian
# chengmai Not Found
# Processing City:vila velha
# Processing City:bloemhof
# Processing City:ulagan
# Processing City:margate
# Processing City:corovode
# Processing City:lavrentiya
# Processing City:vestmannaeyjar
# Processing City:srednekolymsk
# Processing City:kuching
# Processing City:nioro
# Processing City:karratha
# umzimvubu Not Found
# Processing City:anito
# Processing City:brownwood
# Processing City:scarborough
# Processing City:atar
# Processing City:namatanai
# rawannawi Not Found
# Processing City:cidreira
# Processing City:benguela
# jinchengjiang Not Found
# Processing City:san miguel
# Processing City:aranos
# Processing City:ulaanbaatar
# Processing City:zhigansk
# Processing City:maun
# Processing City:juba
# Processing City:vardo
# Processing City:verkhniye kigi
# Processing City:owando
# dinsor Not Found
# Processing City:tyazhinskiy
# Processing City:assiniboia
# Processing City:deputatskiy
# Processing City:anqiu
# Processing City:san vicente
# Processing City:dudinka
# Processing City:kalaswala
# Processing City:ashtian
# Processing City:almeirim
# Processing City:wanaka
# Processing City:ayagoz
# Processing City:saint-joseph
# Processing City:koumac
# Processing City:bengkulu
# Processing City:linxia
# jiroft Not Found
# Processing City:wuwei
# Processing City:ancud
# Processing City:severobaykalsk
# Processing City:syracuse
# Processing City:tubuala
# Processing City:ilula
# Processing City:sheridan
# Processing City:raduzhnyy
# Processing City:faanui
# Processing City:kurilsk
# rungata Not Found
# Processing City:busembatia
# Processing City:chandler
# Processing City:oranjemund
# Processing City:san quintin
# Processing City:robertsport
# Processing City:watrous
# Processing City:marsabit
# Processing City:turbat
# Processing City:rohru
# Processing City:hualmay
# viligili Not Found
# Processing City:waipawa
# Processing City:nishihara
# Processing City:arlit
# Processing City:kaunas
# Processing City:radcliff
# Processing City:maryville
# Processing City:gejiu
# Processing City:riyadh
# Processing City:sassandra
# Processing City:lena
# Processing City:bagdarin
# Processing City:hami
# Processing City:yumen
# Processing City:adra
# Processing City:tucuman
# Processing City:saint anthony
# Processing City:khokhlovo
# Processing City:caravelas
# Processing City:bethanien
# Processing City:suez
# Processing City:monki
# Processing City:vostok
# Processing City:manaure
# Processing City:miramar
# Processing City:kaseda
# Processing City:zhangye
# Processing City:koundara
# Processing City:arganil
# Processing City:albury
# Processing City:port hawkesbury
# Processing City:sorland
# Processing City:nantucket
# Processing City:baruun-urt
# Processing City:zabol
# Processing City:chara
# Processing City:chaykovskiy
# Processing City:imbituba
# Processing City:kamennogorsk
# Processing City:clinton
# Processing City:neiafu
# Processing City:port hardy
# Processing City:kaeo
# Processing City:northam
# Processing City:sarrebourg
# Processing City:port macquarie
# Processing City:goderich
# Processing City:cabedelo
# Processing City:xianyang
# Processing City:fairbanks
# Processing City:campbellton
# Processing City:jiayuguan
# Processing City:bermeo
# Processing City:mount hagen
# Processing City:garden city
# Processing City:la ronge
# Processing City:santa cruz
# Processing City:karatau
# Processing City:salto
# Processing City:natal
# Processing City:noumea
# Processing City:farmington
# Processing City:pimentel
# Processing City:skibbereen
# Processing City:staunton
# Processing City:anjiang
# Processing City:port blair
# Processing City:ulcinj
# Processing City:leshukonskoye
# Processing City:gap
# Processing City:westport
# Processing City:evensk
# Processing City:cayenne
# Processing City:goianesia
# Processing City:praya
# Processing City:seoul
# Processing City:kahului
# kapustin yar-1 Not Found
# Processing City:mercedes
# Processing City:buenos aires
# Processing City:bridgetown
# Processing City:hervey bay
# Processing City:chunoyar
# Processing City:klyuchevskiy
# Processing City:soyo
# Processing City:orthez
# Processing City:kloulklubed
# Processing City:okhotsk
# Processing City:zavetnoye
# Processing City:pljevlja
# Processing City:birigui
# Processing City:gigmoto
# Processing City:valencia
# Processing City:port lincoln
# Processing City:dingzhou
# Processing City:gandajika
# Processing City:bad salzungen
# Processing City:amga
# Processing City:raga
# Processing City:kamuli
# Processing City:matagami
# mrirt Not Found
# Processing City:aluksne
# karkaralinsk Not Found
# Processing City:apatou
# Processing City:vao
# Processing City:bulgan
# Processing City:kununurra
# negele Not Found
# Processing City:henties bay
# Processing City:phuntsholing
# Processing City:sena madureira

# %% [markdown]
# #### Converting Raw Data to DataFrame with desired data organization:

# %%
City_DataFrame = pd.DataFrame(City_Data)

# Coordinates data must be broken apart into separate data columns to isolate Latitude as a variable.
Lat_Lon = City_DataFrame['Coordinates'].to_dict()
Lat_Lon_df = pd.DataFrame(Lat_Lon)

Latitude = pd.DataFrame(Lat_Lon_df.T['lat'])
Latitude.columns = ['Latitude']
Latitude
# Out:
#      Latitude
# 0    -23.1203
# 1     22.0752
# 2     50.7214
# 3    -46.1927
# 4     28.0170
# ..        ...
# 554   48.8125
# 555  -15.7667
# 556  -22.1160
# 557   26.8516
# 558   -9.0656
#
# [559 rows x 1 columns]

# %%
# Latitude can now be added back into the rest of the data.
Weather_Data = pd.concat([City_DataFrame, Latitude], axis=1, join='inner')
Weather_Data
# Out:
#                City Country                          Coordinates  \
# 0           Rikitea      PF  {'lon': -134.9692, 'lat': -23.1203}
# 1             Kapaa      US    {'lon': -159.319, 'lat': 22.0752}
# 2        Solnechnyy      RU    {'lon': 136.6319, 'lat': 50.7214}
# 3           Mataura      NZ   {'lon': 168.8643, 'lat': -46.1927}
# 4      San Patricio      US     {'lon': -97.5169, 'lat': 28.017}
# ..              ...     ...                                  ...
# 554          Bulgan      MN    {'lon': 103.5347, 'lat': 48.8125}
# 555       Kununurra      AU   {'lon': 128.7333, 'lat': -15.7667}
# 556     Henties Bay      NA     {'lon': 14.2845, 'lat': -22.116}
# 557    Phuntsholing      BT     {'lon': 89.3884, 'lat': 26.8516}
# 558  Sena Madureira      BR    {'lon': -68.6569, 'lat': -9.0656}
#
#      Max Temperature  Humidity  Pressure  Cloudiness  Wind Speed        Date  \
# 0              74.16        84      1019           7       19.75  1634963134
# 1              80.58        87      1019          40       11.50  1634963134
# 2              43.70        64      1012          98        2.91  1634963134
# 3              70.36        43      1018          96        3.04  1634963134
# 4              80.46        79      1015          97        8.95  1634963135
# ..               ...       ...       ...         ...         ...         ...
# 554            42.93        32      1022           1        2.28  1634963284
# 555           100.38        34      1009           6        9.22  1634963285
# 556            55.85        88      1018           0        7.52  1634963285
# 557            76.78        74      1017          72        2.68  1634963285
# 558            78.48        75      1008          98        2.86  1634963286
#
#      Latitude
# 0    -23.1203
# 1     22.0752
# 2     50.7214
# 3    -46.1927
# 4     28.0170
# ..        ...
# 554   48.8125
# 555  -15.7667
# 556  -22.1160
# 557   26.8516
# 558   -9.0656
#
# [559 rows x 10 columns]

# %%
# Timestamp from OpenWeather must be converted into pandas datetime to become useful.
Weather_Data['Date'] = pd.to_datetime(Weather_Data['Date'], unit='s')
Weather_Data
# Out:
#                City Country                          Coordinates  \
# 0           Rikitea      PF  {'lon': -134.9692, 'lat': -23.1203}
# 1             Kapaa      US    {'lon': -159.319, 'lat': 22.0752}
# 2        Solnechnyy      RU    {'lon': 136.6319, 'lat': 50.7214}
# 3           Mataura      NZ   {'lon': 168.8643, 'lat': -46.1927}
# 4      San Patricio      US     {'lon': -97.5169, 'lat': 28.017}
# ..              ...     ...                                  ...
# 554          Bulgan      MN    {'lon': 103.5347, 'lat': 48.8125}
# 555       Kununurra      AU   {'lon': 128.7333, 'lat': -15.7667}
# 556     Henties Bay      NA     {'lon': 14.2845, 'lat': -22.116}
# 557    Phuntsholing      BT     {'lon': 89.3884, 'lat': 26.8516}
# 558  Sena Madureira      BR    {'lon': -68.6569, 'lat': -9.0656}
#
#      Max Temperature  Humidity  Pressure  Cloudiness  Wind Speed  \
# 0              74.16        84      1019           7       19.75
# 1              80.58        87      1019          40       11.50
# 2              43.70        64      1012          98        2.91
# 3              70.36        43      1018          96        3.04
# 4              80.46        79      1015          97        8.95
# ..               ...       ...       ...         ...         ...
# 554            42.93        32      1022           1        2.28
# 555           100.38        34      1009           6        9.22
# 556            55.85        88      1018           0        7.52
# 557            76.78        74      1017          72        2.68
# 558            78.48        75      1008          98        2.86
#
#                    Date  Latitude
# 0   2021-10-23 04:25:34  -23.1203
# 1   2021-10-23 04:25:34   22.0752
# 2   2021-10-23 04:25:34   50.7214
# 3   2021-10-23 04:25:34  -46.1927
# 4   2021-10-23 04:25:35   28.0170
# ..                  ...       ...
# 554 2021-10-23 04:28:04   48.8125
# 555 2021-10-23 04:28:05  -15.7667
# 556 2021-10-23 04:28:05  -22.1160
# 557 2021-10-23 04:28:05   26.8516
# 558 2021-10-23 04:28:06   -9.0656
#
# [559 rows x 10 columns]

# %% [markdown]
# #### Creating a CSV file of the dataframe:

# %%
Weather_Data.to_csv('Weather_Data.csv')

# %% [markdown]
# ## Visualizing the Data

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
ax.scatter(Weather_Data['Latitude'], Weather_Data['Max Temperature'], color='r', marker='o')
ax.set_ylabel("Maximum Temperature ($^\circ$F)")
ax.set_xlabel("Latitude (0$^\circ$ is equator)")
ax.set_title('City Latitude vs. Temperature ($^\circ$F)(10/23/21)')
plt.savefig('Latitude_vs_Temperature.png', dpi = 600)
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
ax.scatter(Weather_Data['Latitude'], Weather_Data['Humidity'], color='y',marker='o')
ax.set_ylabel("Humidity(%)")
ax.set_xlabel("Latitude (0$^\circ$ is equator)")
ax.set_title('City Latitude vs. Humidity(%)(10/23/21)')
plt.savefig('Latitude_vs_Humidity.png', dpi = 600)
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
ax.scatter(Weather_Data['Latitude'], Weather_Data['Cloudiness'], color='0.7', marker='o')
ax.set_ylabel("Cloud Cover (%)")
ax.set_xlabel("Latitude (0$^\circ$ is equator)")
ax.set_title('City Latitude vs. Cloudiness(%)(10/23/21)')
plt.savefig('Latitude_vs_Cloudiness.png', dpi = 600)
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
ax.scatter(Weather_Data['Latitude'], Weather_Data['Wind Speed'], color='c', marker='o')
ax.set_ylabel("Wind Speed(mph)")
ax.set_xlabel("Latitude (0$^\circ$ is equator)")
ax.set_title('City Latitude vs. Wind Speed(mph) (10/23/21)')
plt.savefig('Latitude_vs_Wind_Speed.png', dpi = 600)
plt.show()

# %% [markdown]
# # Data Organized as Small Multiples

# %% [markdown]
# ### Weather Characteristics in Relation to Latitude

# %%
fig, ax = plt.subplots(2,2)
ax = ax.flatten()
ax[0].scatter(Weather_Data['Latitude'], Weather_Data['Max Temperature'], color='r', marker='.')
ax[1].scatter(Weather_Data['Latitude'], Weather_Data['Humidity'], color='y', marker='.')
ax[2].scatter(Weather_Data['Latitude'], Weather_Data['Cloudiness'], color='0.7', marker='.')
ax[3].scatter(Weather_Data['Latitude'], Weather_Data['Wind Speed'], color='c', marker='.')

ax[0].set_ylabel("Maximum Temperature ($^\circ$F)")
ax[1].set_ylabel('Humidity(%)')
ax[2].set_ylabel('Cloudiness(%)')
ax[3].set_ylabel('Wind Speed')
ax[2].set_xlabel("Latitude (0$^\circ$ is equator) (10/23/21)")
plt.savefig('Weather_Characteristics.png', dpi = 600)
plt.show()

# %% [markdown]
# ## Visualizing Data with Seaborn

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %% [markdown]
# # Observations
#
# Observations can now be more easily made from the presented data.
#
# ### 1. Distance from the equator plays a significant part in local weather.
# * The maximum temperature is highest just south of the equator.
# * Northern cities are cooler than thier latitudinal counterparts on the other side of the equator.
# * Cities near 60$^\circ$ latitude represent weather that is cool but still with high humidity.
#
# ### 2. Cloud cover is reported in fewer increments than other weather data.
# * Indicated by striation in plot points
#
# ### 3. Wind speed appears to be the most evenly distributed global weather characteristic in this data set.

# %% [markdown]
# # DataCamp Completions
