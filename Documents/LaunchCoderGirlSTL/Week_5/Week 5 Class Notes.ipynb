# %% [markdown]
# # Warm-up
# * Take the belize_Airbnb_listings.csv from last class and create a dataframe that shows the count of properties per host AND minimum price
#
# * What does CSV stand for?
# *Comma Separated Value file
#
# * What is a delimiter?
# * One or more characters used to separate characters in plain text

# %%
import pandas as pd
import numpy as np

belize_listings_path = "C:/Users/Nik/Documents/LaunchCoderGirlSTL/Data-Science-Assignments/course_material/week_04/belize_airbnb_listings.csv"
belize_df = pd.read_csv(belize_listings_path)
belize_df
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1        36690  Mo's Cozy Cabana w/ comfy veranda & access to ...     157752
# 2       108932  Purple House eco solar  w/ ocean & wildlife views     563377
# 3       110483                            Michelo's fuchsia suite     567809
# 4       120115               Seaside Villas Second Floor Unit  #4     604999
# ...        ...                                                ...        ...
# 2791  48283996                                     Magical Island   17994012
# 2792  48287613   The Luxury Suite - Corozal, Bz- 3Bdr/2bthr CASA1  375769845
# 2793  48296096  Lagoon front apartment w/shared pool -  two mi...   76414486
# 2794  48296978                          Beachfront Poolside Condo   15308338
# 2795  48332221           Standard Room - San Ignacio Resort Hotel   60399527
#
# ...

# %% [markdown]
# # API Keys

# %%
from api_keys import api_key

print(api_key)
# Out:
# 32fc4ff2ff36b8311230515e026ad061

# %%
import requests
import pandas as pd

# %%
# requests library/module is used to send all types of http requests
url = 'http://www.example.com'
req = requests.get(url)
print(req.text)
# Out:
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# ...

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
city = 'st. louis'

#q represent the city
req = requests.get(base_url + f'&q={city}')

# %%
#main = json_data['main']
print(main)
     
weather_desc = json_data['weather'][0]['description']
weather_desc

# %%
#loop thru information

cities_list = ['denver', 'st louis', 'phoenix']

city_weather = {'city': [],
               'humidity':[],
               'pressure':[]}
#loop over citid ans add data to dictionary
for city in cities_list
#q represents the city
req = requests.get(base_url + f'&q={city}')
# Out:
#   File "C:\Users\Nik\AppData\Local\Temp/ipykernel_14132/3824797455.py", line 9
#     for city in cities_list
#                            ^
# SyntaxError: invalid syntax

# %%
#add values to our city_weather dictionary
#city_weather['city'].append(data[name])

#city_weather

# %%
url = 'http://www.example.com'
